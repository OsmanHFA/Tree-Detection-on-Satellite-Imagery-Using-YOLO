# %% [markdown]
# # YOLOv8 Installation

# %%
import os 
os.chdir('/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8m')
import matplotlib.pyplot as plt
from ultralytics import YOLO
from IPython.display import display, Image
from PIL import Image
import pandas as pd
import numpy as np

# %%
# Install YOLOv8
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# Setup complete ✅ (4 CPUs, 14.6 GB RAM, 47.9/98.2 GB disk)

# %% [markdown]
# ### Training

# %%
# Training Original Model - YOLOv8m 
# !yolo detect train model=yolov8m.yaml data="/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/data.yaml" workers=2 batch=12 device=0 epochs=100 patience=50 name=yolov8m_normal
# Out:
# New https://pypi.org/project/ultralytics/8.2.71 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# engine/trainer: task=detect, mode=train, model=yolov8m.yaml, data=/home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/data.yaml, epochs=100, time=None, patience=50, batch=12, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=2, project=None, name=yolov8m_normal, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/yolov8m_normal
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776275  ultralytics.nn.modules.head.Detect           [1, [192, 384, 576]]
# YOLOv8m summary: 295 layers, 25856899 parameters, 25856883 gradients, 79.1 GFLOPs
#
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 34.2MB/s]
# AMP: checks passed ✅
# train: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) =
640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.886      0.836      0.889      0.412
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      8.26G       1.66     0.7835      1.316        704        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.926      0.866      0.921      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      6.54G      1.628     0.7675      1.293        863        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.922      0.877       0.92      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100       7.3G      1.616     0.7641      1.297       1163        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.933      0.866      0.918      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      7.31G      1.595     0.7586      1.273        831        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.914      0.873      0.913      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      8.32G      1.596      0.742      1.294        909        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.929      0.867      0.916      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      8.52G      1.591     0.7514      1.279        620        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.942      0.872      0.927      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      8.69G      1.588     0.7549      1.264        469        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.893      0.846        0.9      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      8.84G      1.575     0.7426      1.273        546        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347       0.94      0.866      0.919      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      7.35G      1.584     0.7435      1.289        932        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.941      0.884      0.931      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      7.65G      1.574     0.7306      1.271        931        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.932       0.88      0.926       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      7.53G      1.539     0.7234      1.243        921        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.934      0.882      0.927      0.492
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100       8.2G      1.549     0.7258       1.24        896        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.933      0.885       0.93      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100       7.7G      1.519     0.7135      1.259        763        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.939      0.889      0.934      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      8.33G      1.516     0.7143      1.248        774        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347       0.93      0.893      0.934      0.505
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      6.47G      1.538     0.7358      1.303        796        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.935       0.88       0.92      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      7.43G      1.484     0.7033       1.27        490        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.921      0.883      0.924      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      6.15G      1.514     0.7106      1.295        534        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.939      0.879      0.934      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      6.04G      1.498     0.7081      1.264        604        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.927      0.883      0.917      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      6.42G      1.481     0.6955      1.255        611        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.946      0.882      0.933       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      5.61G      1.478     0.6952      1.269        493        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.935      0.899      0.932      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      6.28G      1.437     0.6801      1.259        600        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.935      0.895      0.929      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      5.95G      1.429     0.6769      1.244        714        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347       0.94      0.896      0.932       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      6.08G      1.434     0.6791      1.249        498        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347       0.93      0.902       0.93      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      6.12G      1.437     0.6751      1.245        581        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.939      0.901      0.934      0.516
#
# 100 epochs completed in 0.440 hours.
# Optimizer stripped from runs/detect/yolov8m_normal/weights/last.pt, 52.0MB
# Optimizer stripped from runs/detect/yolov8m_normal/weights/best.pt, 52.0MB
#
# Validating runs/detect/yolov8m_normal/weights/best.pt...
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# YOLOv8m summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.939      0.901      0.934      0.516
# Speed: 1.8ms preprocess, 9.6ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to runs/detect/yolov8m_normal
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# # Inference on Test Set

# %%
model = YOLO("/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8m/runs/detect/yolov8m_normal/weights/best.pt")  

# Creating directory to store results
test_images_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/images'
output_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/YOLOv8m_normal No Aug Inference'
os.makedirs(output_dir, exist_ok=True)

# List of all test images
test_images = [os.path.join(test_images_dir, img) for img in os.listdir(test_images_dir) if img.endswith('.jpg')]
test_images.sort()

# Run inference on all test images
results = model(test_images)  

# Visualize and save the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Save results to disk
    im_rgb.save(os.path.join(output_dir, f"results_{i}.jpg"))
# Out:
# 0: 640x640 91 trees, 20.4ms
# 1: 640x640 6 trees, 20.4ms
# 2: 640x640 46 trees, 20.4ms
# 3: 640x640 46 trees, 20.4ms
# 4: 640x640 46 trees, 20.4ms
# 5: 640x640 46 trees, 20.4ms
# 6: 640x640 65 trees, 20.4ms
# 7: 640x640 74 trees, 20.4ms
# 8: 640x640 74 trees, 20.4ms
# 9: 640x640 74 trees, 20.4ms
# 10: 640x640 77 trees, 20.4ms
# 11: 640x640 108 trees, 20.4ms
# 12: 640x640 102 trees, 20.4ms
# 13: 640x640 102 trees, 20.4ms
# 14: 640x640 102 trees, 20.4ms
# 15: 640x640 102 trees, 20.4ms
# 16: 640x640 92 trees, 20.4ms
# 17: 640x640 132 trees, 20.4ms
# 18: 640x640 165 trees, 20.4ms
# 19: 640x640 23 trees, 20.4ms
# 20: 640x640 80 trees, 20.4ms
# 21: 640x640 80 trees, 20.4ms
# 22: 640x640 78 trees, 20.4ms
# 23: 640x640 80 trees, 20.4ms
# 24: 640x640 93 trees, 20.4ms
# 25: 640x640 93 trees, 20.4ms
# 26: 640x640 92 trees, 20.4ms
# 27: 640x640 92 trees, 20.4ms
# 28: 640x640 92 trees, 20.4ms
# 29: 640x640 78 trees, 20.4ms
# 30: 640x640 78 trees, 20.4ms
# 31: 640x640 78 trees, 20.4ms
# 32: 640x640 77 trees, 20.4ms
# 33: 640x640 177 trees, 20.4ms
# 34: 640x640 117 trees, 20.4ms
# 35: 640x640 117 trees, 20.4ms
# 36: 640x640 117 trees, 20.4ms
# 37: 640x640 117 trees, 20.4ms
# 38: 640x640 68 trees, 20.4ms
# 39: 640x640 68 trees, 20.4ms
# 40: 640x640 68 trees, 20.4ms
# 41: 640x640 68 trees, 20.4ms
# 42: 640x640 75 trees, 20.4ms
# 43: 640x640 52 trees, 20.4ms
# 44: 640x640 121 trees, 20.4ms
# 45: 640x640 121 trees, 20.4ms
# 46: 640x640 121 trees, 20.4ms
# 47: 640x640 121 trees, 20.4ms
# 48: 640x640 121 trees, 20.4ms
# 49: 640x640 94 trees, 20.4ms
# Speed: 2.3ms preprocess, 20.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# # Ground Truth and MAE

# %%
label_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/labels'

# List of labels
labels = [os.path.join(label_dir, img) for img in os.listdir(label_dir) if img.endswith('.txt')]
labels.sort()

for idx, label in enumerate(labels):
    file = pd.read_csv(label, delimiter=' ', header=None)
    print(f'Ground Truth {idx}: {len(file)} trees')

# %%
# Predictions from YOLO model
predictions = [
    91, 6, 46, 46, 46, 46, 65, 74, 74, 74,
    77, 108, 102, 102, 102, 102, 92, 132, 165, 23,
    80, 80, 78, 80, 93, 93, 92, 92, 92, 78,
    78, 78, 77, 177, 117, 117, 117, 117, 68, 68,
    68, 68, 75, 52, 121, 121, 121, 121, 121, 94
]

# Ground truth from labels
ground_truth = [
    86, 7, 48, 48, 48, 48, 64, 69, 69, 69,
    69, 105, 114, 114, 114, 114, 109, 97, 175, 20,
    72, 72, 72, 72, 89, 89, 89, 89, 89, 77,
    77, 77, 77, 148, 112, 112, 112, 112, 72, 72,
    72, 72, 74, 50, 130, 130, 130, 130, 130, 89
]

# Create a DataFrame to store the results
results_df = pd.DataFrame({
    'Image': [f'Image {i}' for i in range(len(predictions))],
    'Prediction': predictions,
    'Ground Truth': ground_truth
})

# Display the dataframe
print(results_df)

# Calculate Mean Absolute Error (MAE)
mae = (results_df['Prediction'] - results_df['Ground Truth']).abs().mean()

print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
#        Image  Prediction  Ground Truth
# 0    Image 0          91            86
# 1    Image 1           6             7
# 2    Image 2          46            48
# 3    Image 3          46            48
# 4    Image 4          46            48
# 5    Image 5          46            48
# 6    Image 6          65            64
# 7    Image 7          74            69
# 8    Image 8          74            69
# 9    Image 9          74            69
# 10  Image 10          77            69
# 11  Image 11         108           105
# 12  Image 12         102           114
# 13  Image 13         102           114
# 14  Image 14         102           114
# 15  Image 15         102           114
# 16  Image 16          92           109
# 17  Image 17         132            97
# 18  Image 18         165           175
# 19  Image 19          23            20
# 20  Image 20          80            72
# 21  Image 21          80            72
# 22  Image 22          78            72
# 23  Image 23          80            72
# 24  Image 24          93            89
# 25  Image 25          93            89
# 26  Image 26          92            89
# 27  Image 27          92            89
# 28  Image 28          92            89
# 29  Image 29          78            77
# 30  Image 30          78            77
# 31  Image 31          78            77
# 32  Image 32          77            77
# 33  Image 33         177           148
# 34  Image 34         117           112
# 35  Image 35         117           112
# 36  Image 36         117           112
# 37  Image 37         117           112
# 38  Image 38          68            72
# 39  Image 39          68            72
# 40  Image 40          68            72
# 41  Image 41          68            72
# 42  Image 42          75            74
# 43  Image 43          52            50
# 44  Image 44         121           130
# 45  Image 45         121           130
# 46  Image 46         121           130
# 47  Image 47         121           130
# 48  Image 48         121           130
# 49  Image 49          94            89
# Mean Absolute Error (MAE): 6.44

# %% [markdown]
# # Inference on Satellite Imagery

# %%
# Load our trained YOLO model
model = YOLO("/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8m/runs/detect/yolov8m_normal/weights/best.pt")  

# Creating directory to store results
sat_images_dir = '/home/jupyter/ee_tree_counting/Sample Images'

save_dir = '/home/jupyter/ee_tree_counting/Sample Images/YOLOv8m_normal Predictions'
os.makedirs(save_dir, exist_ok=True)

# List of all test images
sat_imgs = [os.path.join(sat_images_dir, img) for img in os.listdir(sat_images_dir) if img.endswith('.png') or img.endswith('.jpg') or img.endswith('.tif')]
sat_imgs.sort()

# Run inference on all test images
results = model(sat_imgs)

# Visualize and save the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Save results to disk
    im_rgb.save(os.path.join(save_dir, f"results_{i}.jpg"))
# Out:
# 0: 640x640 91 trees, 33.8ms
# 1: 640x640 9 trees, 33.8ms
# 2: 640x640 12 trees, 33.8ms
# Speed: 2.5ms preprocess, 33.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# # mAP on Validation Set

# %%
# !yolo detect val model="/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8s/runs/detect/yolov8s_normal/weights/best.pt" data="/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/data.yaml" iou=0.5 name=yolov8s-normal-mAPval
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# YOLOv8s summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/v
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.929      0.873      0.918      0.472
# Speed: 2.2ms preprocess, 9.4ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to runs/detect/yolov8s-normal-mAPval
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ### Training a Modified Model (Small Objects)

# %%
# Training a Modified Model (Small Objects)
# !yolo detect train model=yolov8m-small.yaml data="/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/data.yaml" workers=2 batch=12 device=0 epochs=100 patience=50 name=yolov8m_small
# Out:
# New https://pypi.org/project/ultralytics/8.2.71 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# engine/trainer: task=detect, mode=train, model=yolov8m-small.yaml, data=/home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/data.yaml, epochs=100, time=None, patience=50, batch=12, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=2, project=None, name=yolov8m_small, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/yolov8m_small
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  4   1444864  ultralytics.nn.modules.block.C2f             [256, 256, 4, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  4   5773312  ultralytics.nn.modules.block.C2f             [512, 512, 4, True]
#   7                  -1  1   1182208  ultralytics.nn.modules.block.SPPF            [512, 1024, 5]
#   8                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#   9             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  10                  -1  2   1050624  ultralytics.nn.modules.block.C2f             [1280, 256, 2]
#  11                [10]  1   1369681  ultralytics.nn.modules.head.Detect           [1, [256]]
# YOLOv8m-small summary: 162 layers, 12570257 parameters, 12570241 gradients, 93.8 GFLOPs
#
# Freezing layer 'model.11.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 123, len(boxes) = 31838. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.12 (you have 1.4.11). Upgrade using: pip install --upgrade albumentations
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/v
# Plotting labels to runs/detect/yolov8m_small/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      6.71G      1.581     0.7222      1.293        831        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.931      0.872       0.91      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      7.74G      1.576      0.706      1.307        909        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347       0.92      0.876      0.915      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      7.83G       1.57     0.7141      1.294        620        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.927      0.878      0.919      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      7.95G       1.56     0.7098      1.277        469        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.935      0.886      0.933      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      7.91G      1.547     0.6994      1.285        546        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.928       0.87      0.912      0.478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      6.94G      1.545     0.7046      1.296        932        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.925      0.875      0.915       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      6.95G      1.546     0.6955       1.28        931        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.929      0.888      0.927       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      6.91G      1.519      0.686      1.257        921        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.931      0.889      0.926      0.492
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      7.42G      1.528     0.6864      1.255        896        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.932      0.878      0.923      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      6.98G      1.494     0.6745      1.271        763        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.939      0.887      0.929      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      7.59G      1.498     0.6777      1.261        774        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.935      0.893      0.937      0.507
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      6.31G       1.53      0.686      1.318        796        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.925      0.887      0.927       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      6.84G      1.463     0.6729      1.279        490        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.942      0.883      0.928      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      6.03G      1.481     0.6738      1.299        534        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.941      0.885      0.934      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      5.94G      1.465     0.6628      1.269        604        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.945      0.889      0.933      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      6.28G       1.44     0.6557      1.258        611        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.944      0.894      0.939      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      5.92G      1.453     0.6558      1.276        493        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.932      0.891      0.928      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      6.16G      1.411     0.6438      1.264        600        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.942      0.889      0.933      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      5.87G      1.401     0.6379      1.251        714        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.941      0.892      0.934       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      5.97G      1.402      0.643      1.253        498        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.939      0.896      0.935      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100         6G      1.401     0.6358      1.249        581        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.942      0.892      0.933      0.515
#
# 100 epochs completed in 0.401 hours.
# Optimizer stripped from runs/detect/yolov8m_small/weights/last.pt, 25.3MB
# Optimizer stripped from runs/detect/yolov8m_small/weights/best.pt, 25.3MB
#
# Validating runs/detect/yolov8m_small/weights/best.pt...
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# YOLOv8m-small summary (fused): 120 layers, 12561233 parameters, 0 gradients, 93.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.938      0.895      0.935      0.516
# Speed: 2.3ms preprocess, 10.2ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs/detect/yolov8m_small
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# # Inference on Test Set

# %%
model = YOLO("/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8m/runs/detect/yolov8m_small/weights/best.pt")  

# Creating directory to store results
test_images_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/images'
output_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/YOLOv8m_small No Aug Inference'
os.makedirs(output_dir, exist_ok=True)

# List of all test images
test_images = [os.path.join(test_images_dir, img) for img in os.listdir(test_images_dir) if img.endswith('.jpg')]
test_images.sort()

# Run inference on all test images
results = model(test_images)  

# Visualize and save the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Save results to disk
    im_rgb.save(os.path.join(output_dir, f"results_{i}.jpg"))
# Out:
# 0: 640x640 92 trees, 22.4ms
# 1: 640x640 6 trees, 22.4ms
# 2: 640x640 50 trees, 22.4ms
# 3: 640x640 51 trees, 22.4ms
# 4: 640x640 51 trees, 22.4ms
# 5: 640x640 51 trees, 22.4ms
# 6: 640x640 65 trees, 22.4ms
# 7: 640x640 75 trees, 22.4ms
# 8: 640x640 75 trees, 22.4ms
# 9: 640x640 75 trees, 22.4ms
# 10: 640x640 76 trees, 22.4ms
# 11: 640x640 105 trees, 22.4ms
# 12: 640x640 111 trees, 22.4ms
# 13: 640x640 111 trees, 22.4ms
# 14: 640x640 111 trees, 22.4ms
# 15: 640x640 110 trees, 22.4ms
# 16: 640x640 96 trees, 22.4ms
# 17: 640x640 142 trees, 22.4ms
# 18: 640x640 172 trees, 22.4ms
# 19: 640x640 27 trees, 22.4ms
# 20: 640x640 77 trees, 22.4ms
# 21: 640x640 77 trees, 22.4ms
# 22: 640x640 73 trees, 22.4ms
# 23: 640x640 77 trees, 22.4ms
# 24: 640x640 97 trees, 22.4ms
# 25: 640x640 97 trees, 22.4ms
# 26: 640x640 94 trees, 22.4ms
# 27: 640x640 94 trees, 22.4ms
# 28: 640x640 94 trees, 22.4ms
# 29: 640x640 74 trees, 22.4ms
# 30: 640x640 74 trees, 22.4ms
# 31: 640x640 74 trees, 22.4ms
# 32: 640x640 76 trees, 22.4ms
# 33: 640x640 187 trees, 22.4ms
# 34: 640x640 125 trees, 22.4ms
# 35: 640x640 126 trees, 22.4ms
# 36: 640x640 125 trees, 22.4ms
# 37: 640x640 125 trees, 22.4ms
# 38: 640x640 69 trees, 22.4ms
# 39: 640x640 68 trees, 22.4ms
# 40: 640x640 69 trees, 22.4ms
# 41: 640x640 69 trees, 22.4ms
# 42: 640x640 74 trees, 22.4ms
# 43: 640x640 51 trees, 22.4ms
# 44: 640x640 127 trees, 22.4ms
# 45: 640x640 125 trees, 22.4ms
# 46: 640x640 125 trees, 22.4ms
# 47: 640x640 127 trees, 22.4ms
# 48: 640x640 127 trees, 22.4ms
# 49: 640x640 93 trees, 22.4ms
# Speed: 2.0ms preprocess, 22.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# # Ground Truth

# %%
label_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/labels'

# List of labels
labels = [os.path.join(label_dir, img) for img in os.listdir(label_dir) if img.endswith('.txt')]
labels.sort()

for idx, label in enumerate(labels):
    file = pd.read_csv(label, delimiter=' ', header=None)
    print(f'Ground Truth {idx}: {len(file)} trees')

# %%
predictions = [
    92, 6, 50, 51, 51, 51, 65, 75, 75, 75,
    76, 105, 111, 111, 111, 110, 96, 142, 172, 27,
    77, 77, 73, 77, 97, 97, 94, 94, 94, 74,
    74, 74, 76, 187, 125, 126, 125, 125, 69, 68,
    69, 69, 74, 51, 127, 125, 125, 127, 127, 93
]

# Ground truth from labels
ground_truth = [
    86, 7, 48, 48, 48, 48, 64, 69, 69, 69,
    69, 105, 114, 114, 114, 114, 109, 97, 175, 20,
    72, 72, 72, 72, 89, 89, 89, 89, 89, 77,
    77, 77, 77, 148, 112, 112, 112, 112, 72, 72,
    72, 72, 74, 50, 130, 130, 130, 130, 130, 89
]

# Create a DataFrame to store the results
results_df = pd.DataFrame({
    'Image': [f'Image {i}' for i in range(len(predictions))],
    'Prediction': predictions,
    'Ground Truth': ground_truth
})

# Display the dataframe
print(results_df)

# Calculate Mean Absolute Error (MAE)
mae = (results_df['Prediction'] - results_df['Ground Truth']).abs().mean()

print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
#        Image  Prediction  Ground Truth
# 0    Image 0          92            86
# 1    Image 1           6             7
# 2    Image 2          50            48
# 3    Image 3          51            48
# 4    Image 4          51            48
# 5    Image 5          51            48
# 6    Image 6          65            64
# 7    Image 7          75            69
# 8    Image 8          75            69
# 9    Image 9          75            69
# 10  Image 10          76            69
# 11  Image 11         105           105
# 12  Image 12         111           114
# 13  Image 13         111           114
# 14  Image 14         111           114
# 15  Image 15         110           114
# 16  Image 16          96           109
# 17  Image 17         142            97
# 18  Image 18         172           175
# 19  Image 19          27            20
# 20  Image 20          77            72
# 21  Image 21          77            72
# 22  Image 22          73            72
# 23  Image 23          77            72
# 24  Image 24          97            89
# 25  Image 25          97            89
# 26  Image 26          94            89
# 27  Image 27          94            89
# 28  Image 28          94            89
# 29  Image 29          74            77
# 30  Image 30          74            77
# 31  Image 31          74            77
# 32  Image 32          76            77
# 33  Image 33         187           148
# 34  Image 34         125           112
# 35  Image 35         126           112
# 36  Image 36         125           112
# 37  Image 37         125           112
# 38  Image 38          69            72
# 39  Image 39          68            72
# 40  Image 40          69            72
# 41  Image 41          69            72
# 42  Image 42          74            74
# 43  Image 43          51            50
# 44  Image 44         127           130
# 45  Image 45         125           130
# 46  Image 46         125           130
# 47  Image 47         127           130
# 48  Image 48         127           130
# 49  Image 49          93            89
# Mean Absolute Error (MAE): 6.22

# %% [markdown]
# # Inference on Satellite Images

# %%
# Load our trained YOLO model
model = YOLO("/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8s/runs/detect/yolov8s_small/weights/best.pt")  

# Creating directory to store results
sat_images_dir = '/home/jupyter/ee_tree_counting/Sample Images'

save_dir = '/home/jupyter/ee_tree_counting/Sample Images/YOLOv8s_small Predictions'
os.makedirs(save_dir, exist_ok=True)

# List of all test images
sat_imgs = [os.path.join(sat_images_dir, img) for img in os.listdir(sat_images_dir) if img.endswith('.png') or img.endswith('.jpg') or img.endswith('.tif')]
sat_imgs.sort()

# Run inference on all test images
results = model(sat_imgs)

# Visualize and save the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Save results to disk
    im_rgb.save(os.path.join(save_dir, f"results_{i}.jpg"))
# Out:
# 0: 640x640 75 trees, 25.1ms
# 1: 640x640 14 trees, 25.1ms
# 2: 640x640 12 trees, 25.1ms
# Speed: 2.4ms preprocess, 25.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
