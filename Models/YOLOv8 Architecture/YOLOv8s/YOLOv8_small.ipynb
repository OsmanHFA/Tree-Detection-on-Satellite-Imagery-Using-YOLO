# %% [markdown]
# # YOLOv8 Installation

# %%
import os 
os.chdir('/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8s')
import matplotlib.pyplot as plt
from ultralytics import YOLO
from IPython.display import display, Image
from PIL import Image
import pandas as pd
import numpy as np

# %%
# Install YOLOv8
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# Setup complete ✅ (4 CPUs, 14.6 GB RAM, 46.2/98.2 GB disk)

# %% [markdown]
# ### Training

# %%
# Training Original Model
# !yolo detect train model=yolov8s.yaml data="/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/data.yaml" workers=2 batch=12 device=0 epochs=100 patience=50 name=yolov8s_normal
# Out:
# New https://pypi.org/project/ultralytics/8.2.67 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# engine/trainer: task=detect, mode=train, model=yolov8s.yaml, data=/home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/data.yaml, epochs=100, time=None, patience=50, batch=12, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=2, project=None, name=yolov8s_normal, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/yolov8s_normal
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# YOLOv8s summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 26.4MB/s]
# AMP: checks passed ✅
# train: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 123, len(boxes) = 31838. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.12 (you have 1.4.11). Upgrade using: pip install --upgrade albumentations
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/v
# Plotting labels to runs/detect/yolov8s_normal/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.00046875), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/yolov8s_normal
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      4.83G      5.355      2.892      4.028        827        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347   5.65e-05    0.00023    2.9e-05    2.9e-06
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      5.25G      4.016      2.005      3.674        480        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347     0.0117     0.0476    0.00663    0.00161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      5.06G       3.28      1.683      2.862        946        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.216      0.197      0.147     0.0499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100       5.4G      2.814      1.487      2.465        830        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347       0.13      0.494       0.13     0.0516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      6.18G      2.615      1.356      2.236        733        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.244      0.393      0.177     0.0619
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.51G      2.543      1.282      2.095        670        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.454      0.376      0.347      0.117
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      6.18G      2.485      1.298      2.024        944        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.165     0.0824     0.0528     0.0166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      5.51G      2.416      1.233      1.903        522        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.628      0.714      0.623      0.231
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      5.36G      2.391      1.233      1.885        805        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.569      0.659      0.558      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      5.55G       2.35      1.205      1.817        556        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.762      0.734      0.716       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      5.32G       2.36      1.206      1.804        636        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347       0.62      0.711      0.627      0.245
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      6.12G      2.276      1.165      1.758        897        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347       0.76      0.732      0.725      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      4.99G      2.249      1.137      1.713        790        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.779      0.712      0.723      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/
640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347       0.91      0.852      0.893      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      4.31G      1.618     0.7554      1.343        611        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.921      0.859      0.914      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      3.51G      1.612     0.7637      1.356        493        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.909      0.861      0.906      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      4.18G      1.591     0.7462      1.356        600        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.908      0.861      0.908      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      3.84G      1.586     0.7475      1.342        714        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.917      0.866      0.913      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      3.96G      1.588     0.7472      1.344        498        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.928      0.867       0.92      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      4.02G      1.591      0.742       1.34        581        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.928      0.867      0.918      0.478
#
# 100 epochs completed in 0.233 hours.
# Optimizer stripped from runs/detect/yolov8s_normal/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/yolov8s_normal/weights/best.pt, 22.5MB
#
# Validating runs/detect/yolov8s_normal/weights/best.pt...
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# YOLOv8s summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.928      0.867      0.918      0.478
# Speed: 2.3ms preprocess, 4.3ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/yolov8s_normal
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# # Inference on Test Set

# %%
model = YOLO("/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8s/runs/detect/yolov8s_normal/weights/best.pt")  

# Creating directory to store results
test_images_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/images'
output_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/YOLOv8s_normal No Aug Inference'
os.makedirs(output_dir, exist_ok=True)

# List of all test images
test_images = [os.path.join(test_images_dir, img) for img in os.listdir(test_images_dir) if img.endswith('.jpg')]
test_images.sort()

# Run inference on all test images
results = model(test_images)  

# Visualize and save the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Save results to disk
    im_rgb.save(os.path.join(output_dir, f"results_{i}.jpg"))
# Out:
# 0: 640x640 93 trees, 8.9ms
# 1: 640x640 7 trees, 8.9ms
# 2: 640x640 49 trees, 8.9ms
# 3: 640x640 52 trees, 8.9ms
# 4: 640x640 52 trees, 8.9ms
# 5: 640x640 52 trees, 8.9ms
# 6: 640x640 66 trees, 8.9ms
# 7: 640x640 78 trees, 8.9ms
# 8: 640x640 78 trees, 8.9ms
# 9: 640x640 78 trees, 8.9ms
# 10: 640x640 80 trees, 8.9ms
# 11: 640x640 109 trees, 8.9ms
# 12: 640x640 107 trees, 8.9ms
# 13: 640x640 107 trees, 8.9ms
# 14: 640x640 107 trees, 8.9ms
# 15: 640x640 108 trees, 8.9ms
# 16: 640x640 88 trees, 8.9ms
# 17: 640x640 134 trees, 8.9ms
# 18: 640x640 170 trees, 8.9ms
# 19: 640x640 25 trees, 8.9ms
# 20: 640x640 77 trees, 8.9ms
# 21: 640x640 77 trees, 8.9ms
# 22: 640x640 78 trees, 8.9ms
# 23: 640x640 77 trees, 8.9ms
# 24: 640x640 86 trees, 8.9ms
# 25: 640x640 86 trees, 8.9ms
# 26: 640x640 85 trees, 8.9ms
# 27: 640x640 85 trees, 8.9ms
# 28: 640x640 85 trees, 8.9ms
# 29: 640x640 78 trees, 8.9ms
# 30: 640x640 78 trees, 8.9ms
# 31: 640x640 78 trees, 8.9ms
# 32: 640x640 77 trees, 8.9ms
# 33: 640x640 141 trees, 8.9ms
# 34: 640x640 121 trees, 8.9ms
# 35: 640x640 118 trees, 8.9ms
# 36: 640x640 121 trees, 8.9ms
# 37: 640x640 121 trees, 8.9ms
# 38: 640x640 77 trees, 8.9ms
# 39: 640x640 77 trees, 8.9ms
# 40: 640x640 77 trees, 8.9ms
# 41: 640x640 77 trees, 8.9ms
# 42: 640x640 75 trees, 8.9ms
# 43: 640x640 51 trees, 8.9ms
# 44: 640x640 132 trees, 8.9ms
# 45: 640x640 130 trees, 8.9ms
# 46: 640x640 130 trees, 8.9ms
# 47: 640x640 132 trees, 8.9ms
# 48: 640x640 132 trees, 8.9ms
# 49: 640x640 92 trees, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# # Ground Truth and MAE

# %%
label_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/labels'

# List of labels
labels = [os.path.join(label_dir, img) for img in os.listdir(label_dir) if img.endswith('.txt')]
labels.sort()

for idx, label in enumerate(labels):
    file = pd.read_csv(label, delimiter=' ', header=None)
    print(f'Ground Truth {idx}: {len(file)} trees')

# %%
# Predictions from YOLO model
predictions = [
    93, 7, 49, 52, 52, 52, 66, 78, 78, 78,
    80, 109, 107, 107, 107, 108, 88, 134, 170, 25,
    77, 77, 78, 77, 86, 86, 85, 85, 85, 78,
    78, 78, 77, 141, 121, 118, 121, 121, 77, 77,
    77, 77, 75, 51, 132, 130, 130, 132, 132, 92
]

# Ground truth from labels
ground_truth = [
    86, 7, 48, 48, 48, 48, 64, 69, 69, 69,
    69, 105, 114, 114, 114, 114, 109, 97, 175, 20,
    72, 72, 72, 72, 89, 89, 89, 89, 89, 77,
    77, 77, 77, 148, 112, 112, 112, 112, 72, 72,
    72, 72, 74, 50, 130, 130, 130, 130, 130, 89
]

# Create a DataFrame to store the results
results_df = pd.DataFrame({
    'Image': [f'Image {i}' for i in range(len(predictions))],
    'Prediction': predictions,
    'Ground Truth': ground_truth
})

# Display the dataframe
print(results_df)

# Calculate Mean Absolute Error (MAE)
mae = (results_df['Prediction'] - results_df['Ground Truth']).abs().mean()

print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
#        Image  Prediction  Ground Truth
# 0    Image 0          93            86
# 1    Image 1           7             7
# 2    Image 2          49            48
# 3    Image 3          52            48
# 4    Image 4          52            48
# 5    Image 5          52            48
# 6    Image 6          66            64
# 7    Image 7          78            69
# 8    Image 8          78            69
# 9    Image 9          78            69
# 10  Image 10          80            69
# 11  Image 11         109           105
# 12  Image 12         107           114
# 13  Image 13         107           114
# 14  Image 14         107           114
# 15  Image 15         108           114
# 16  Image 16          88           109
# 17  Image 17         134            97
# 18  Image 18         170           175
# 19  Image 19          25            20
# 20  Image 20          77            72
# 21  Image 21          77            72
# 22  Image 22          78            72
# 23  Image 23          77            72
# 24  Image 24          86            89
# 25  Image 25          86            89
# 26  Image 26          85            89
# 27  Image 27          85            89
# 28  Image 28          85            89
# 29  Image 29          78            77
# 30  Image 30          78            77
# 31  Image 31          78            77
# 32  Image 32          77            77
# 33  Image 33         141           148
# 34  Image 34         121           112
# 35  Image 35         118           112
# 36  Image 36         121           112
# 37  Image 37         121           112
# 38  Image 38          77            72
# 39  Image 39          77            72
# 40  Image 40          77            72
# 41  Image 41          77            72
# 42  Image 42          75            74
# 43  Image 43          51            50
# 44  Image 44         132           130
# 45  Image 45         130           130
# 46  Image 46         130           130
# 47  Image 47         132           130
# 48  Image 48         132           130
# 49  Image 49          92            89
# Mean Absolute Error (MAE): 5.44

# %% [markdown]
# # Inference on Satellite Imagery

# %%
# Load our trained YOLO model
model = YOLO("/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8s/runs/detect/yolov8s_normal/weights/best.pt")  

# Creating directory to store results
sat_images_dir = '/home/jupyter/ee_tree_counting/Sample Images'

save_dir = '/home/jupyter/ee_tree_counting/Sample Images/YOLOv8s_normal Predictions'
os.makedirs(save_dir, exist_ok=True)

# List of all test images
sat_imgs = [os.path.join(sat_images_dir, img) for img in os.listdir(sat_images_dir) if img.endswith('.png') or img.endswith('.jpg') or img.endswith('.tif')]
sat_imgs.sort()

# Run inference on all test images
results = model(sat_imgs)

# Visualize and save the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Save results to disk
    im_rgb.save(os.path.join(save_dir, f"results_{i}.jpg"))
# Out:
# 0: 640x640 91 trees, 13.9ms
# 1: 640x640 18 trees, 13.9ms
# 2: 640x640 14 trees, 13.9ms
# Speed: 16.7ms preprocess, 13.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# # mAP on Validation Set

# %%
# !yolo detect val model="/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8s/runs/detect/yolov8s_normal/weights/best.pt" data="/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/data.yaml" iou=0.5 name=yolov8s-normal-mAPval
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# YOLOv8s summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/v
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.929      0.873      0.918      0.472
# Speed: 2.2ms preprocess, 9.4ms inference, 0.0ms loss, 3.7ms postprocess per image
# Results saved to runs/detect/yolov8s-normal-mAPval
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ### Training a Modified Model - YOLOv8-small

# %% [markdown]
# # Final YOLOv8-small Training (after yaml file fix)

# %%
# !yolo detect train model=yolov8s-small.yaml data="/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/data.yaml" workers=2 batch=12 device=0 epochs=100 patience=50 name=yolov8s_small_trial
# Out:
# New https://pypi.org/project/ultralytics/8.2.79 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# engine/trainer: task=detect, mode=train, model=yolov8s-small.yaml, data=/home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/data.yaml, epochs=100, time=None, patience=50, batch=12, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=2, project=None, name=yolov8s_small_trial, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/yolov8s_small_trial
# Overriding model.yaml nc=2 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1    296192  ultralytics.nn.modules.block.SPPF            [256, 512, 5]
#   8                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#   9             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  10                  -1  1    180992  ultralytics.nn.modules.block.C2f             [640, 128, 1]
#  11                [10]  1    410577  ultralytics.nn.modules.head.Detect           [1, [128]]
# YOLOv8s-small summary: 120 layers, 2291825 parameters, 2291809 gradients, 18.2 GFLOPs
#
# Freezing layer 'model.11.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 123, len(boxes) = 31838. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.14 (you have 1.4.11). Upgrade using: pip install --upgrade albumentations
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/v
# Plotting labels to runs/detect/yolov8s_small_trial/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 30 weight(decay=0.0), 33 weight(decay=0.00046875), 32 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/yolov8s_small_trial
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      3.83G       5.48      2.877      3.982        827        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347    0.00667     0.0271    0.00477    0.00119
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      4.09G      4.331      1.992      3.478        480        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347     0.0225     0.0918     0.0148    0.00445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      3.94G      3.661      1.746      2.917        946        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347    0.00972     0.0396     0.0104    0.00238
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.19G      3.026      1.653      2.586        830        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.233       0.35      0.142     0.0481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      4.79G      2.737      1.484      2.403        733        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347       0.46      0.606      0.431      0.159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      3.49G      2.646      1.384      2.241        670        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.573       0.57      0.516      0.184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      4.79G      2.551      1.356      2.142        944        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.345      0.377      0.257     0.0777
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.28G      2.459       1.28      2.014        522        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.574      0.584      0.536      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      4.17G        2.4      1.266      1.978        805        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.618      0.658      0.599       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.31G      2.378      1.227      1.889        556        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.704      0.707      0.697      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.14G      2.381      1.212      1.866        636        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.746      0.706      0.717      0.284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.75G      2.307      1.156       1.81        897        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.748      0.756      0.731      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100       3.9G      2.282      1.135       1.75        790        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.819      0.723       0.76      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      4.04G      2.285      1.149      1.764        675        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.702      0.674      0.652      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.66G      2.281      1.163       1.76        711        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.745      0.729      0.747      0.292
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      4.66G      2.222      1.118      1.692        861        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.795      0.749      0.758      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      4.71G      2.223       1.12       1.71        857        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.778      0.741      0.745      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      4.65G      2.212      1.117      1.681        799        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.782      0.761      0.765      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      4.28G      2.172      1.103      1.664        875        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.855      0.769      0.803      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      4.28G      2.166      1.086      1.641       1197        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.833      0.778      0.806      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/
640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.929      0.879      0.924      0.492
#
# 100 epochs completed in 0.169 hours.
# Optimizer stripped from runs/detect/yolov8s_small_trial/weights/last.pt, 4.7MB
# Optimizer stripped from runs/detect/yolov8s_small_trial/weights/best.pt, 4.7MB
#
# Validating runs/detect/yolov8s_small_trial/weights/best.pt...
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# YOLOv8s-small summary (fused): 90 layers, 2288209 parameters, 0 gradients, 18.0 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.928      0.879      0.924      0.492
# Speed: 1.2ms preprocess, 3.3ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/yolov8s_small_trial
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# # Inference on Test Set

# %%
model = YOLO("/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8s/runs/detect/yolov8s_small_trial/weights/best.pt")  

# Creating directory to store results
test_images_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/images'
output_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/YOLOv8s_small No Aug Inference'
os.makedirs(output_dir, exist_ok=True)

# List of all test images
test_images = [os.path.join(test_images_dir, img) for img in os.listdir(test_images_dir) if img.endswith('.jpg')]
test_images.sort()

# Run inference on all test images
results = model(test_images)

# Visualize and save the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Save results to disk
    im_rgb.save(os.path.join(output_dir, f"results_{i}.jpg"))
# Out:
# 0: 640x640 89 trees, 7.3ms
# 1: 640x640 5 trees, 7.3ms
# 2: 640x640 45 trees, 7.3ms
# 3: 640x640 46 trees, 7.3ms
# 4: 640x640 46 trees, 7.3ms
# 5: 640x640 46 trees, 7.3ms
# 6: 640x640 65 trees, 7.3ms
# 7: 640x640 76 trees, 7.3ms
# 8: 640x640 76 trees, 7.3ms
# 9: 640x640 76 trees, 7.3ms
# 10: 640x640 77 trees, 7.3ms
# 11: 640x640 106 trees, 7.3ms
# 12: 640x640 115 trees, 7.3ms
# 13: 640x640 115 trees, 7.3ms
# 14: 640x640 115 trees, 7.3ms
# 15: 640x640 114 trees, 7.3ms
# 16: 640x640 88 trees, 7.3ms
# 17: 640x640 131 trees, 7.3ms
# 18: 640x640 173 trees, 7.3ms
# 19: 640x640 17 trees, 7.3ms
# 20: 640x640 73 trees, 7.3ms
# 21: 640x640 73 trees, 7.3ms
# 22: 640x640 74 trees, 7.3ms
# 23: 640x640 73 trees, 7.3ms
# 24: 640x640 80 trees, 7.3ms
# 25: 640x640 80 trees, 7.3ms
# 26: 640x640 81 trees, 7.3ms
# 27: 640x640 81 trees, 7.3ms
# 28: 640x640 81 trees, 7.3ms
# 29: 640x640 75 trees, 7.3ms
# 30: 640x640 75 trees, 7.3ms
# 31: 640x640 75 trees, 7.3ms
# 32: 640x640 75 trees, 7.3ms
# 33: 640x640 169 trees, 7.3ms
# 34: 640x640 117 trees, 7.3ms
# 35: 640x640 115 trees, 7.3ms
# 36: 640x640 117 trees, 7.3ms
# 37: 640x640 117 trees, 7.3ms
# 38: 640x640 74 trees, 7.3ms
# 39: 640x640 73 trees, 7.3ms
# 40: 640x640 74 trees, 7.3ms
# 41: 640x640 74 trees, 7.3ms
# 42: 640x640 77 trees, 7.3ms
# 43: 640x640 48 trees, 7.3ms
# 44: 640x640 126 trees, 7.3ms
# 45: 640x640 125 trees, 7.3ms
# 46: 640x640 125 trees, 7.3ms
# 47: 640x640 126 trees, 7.3ms
# 48: 640x640 126 trees, 7.3ms
# 49: 640x640 89 trees, 7.3ms
# Speed: 2.2ms preprocess, 7.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Predictions from YOLO model
predictions = [
    89, 5, 45, 46, 46, 46, 65, 76, 76, 76,
    77, 106, 115, 115, 115, 114, 88, 131, 173, 17,
    73, 73, 74, 73, 80, 80, 81, 81, 81, 75,
    75, 75, 75, 169, 117, 115, 117, 117, 74, 73,
    74, 74, 77, 48, 126, 125, 125, 126, 126, 89
]

# Ground truth from labels
ground_truth = [
    86, 7, 48, 48, 48, 48, 64, 69, 69, 69,
    69, 105, 114, 114, 114, 114, 109, 97, 175, 20,
    72, 72, 72, 72, 89, 89, 89, 89, 89, 77,
    77, 77, 77, 148, 112, 112, 112, 112, 72, 72,
    72, 72, 74, 50, 130, 130, 130, 130, 130, 89
]

# Create a DataFrame to store the results
results_df = pd.DataFrame({
    'Image': [f'Image {i}' for i in range(len(predictions))],
    'Prediction': predictions,
    'Ground Truth': ground_truth
})

# Display the dataframe
print(results_df)

# Calculate Mean Absolute Error (MAE)
mae = (results_df['Prediction'] - results_df['Ground Truth']).abs().mean()

print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
#        Image  Prediction  Ground Truth
# 0    Image 0          89            86
# 1    Image 1           5             7
# 2    Image 2          45            48
# 3    Image 3          46            48
# 4    Image 4          46            48
# 5    Image 5          46            48
# 6    Image 6          65            64
# 7    Image 7          76            69
# 8    Image 8          76            69
# 9    Image 9          76            69
# 10  Image 10          77            69
# 11  Image 11         106           105
# 12  Image 12         115           114
# 13  Image 13         115           114
# 14  Image 14         115           114
# 15  Image 15         114           114
# 16  Image 16          88           109
# 17  Image 17         131            97
# 18  Image 18         173           175
# 19  Image 19          17            20
# 20  Image 20          73            72
# 21  Image 21          73            72
# 22  Image 22          74            72
# 23  Image 23          73            72
# 24  Image 24          80            89
# 25  Image 25          80            89
# 26  Image 26          81            89
# 27  Image 27          81            89
# 28  Image 28          81            89
# 29  Image 29          75            77
# 30  Image 30          75            77
# 31  Image 31          75            77
# 32  Image 32          75            77
# 33  Image 33         169           148
# 34  Image 34         117           112
# 35  Image 35         115           112
# 36  Image 36         117           112
# 37  Image 37         117           112
# 38  Image 38          74            72
# 39  Image 39          73            72
# 40  Image 40          74            72
# 41  Image 41          74            72
# 42  Image 42          77            74
# 43  Image 43          48            50
# 44  Image 44         126           130
# 45  Image 45         125           130
# 46  Image 46         125           130
# 47  Image 47         126           130
# 48  Image 48         126           130
# 49  Image 49          89            89
# Mean Absolute Error (MAE): 4.72
