# %% [markdown]
# ## Train Normal and Small YOLOv8 with Tuned Hyperparameters/Augmentations

# %%
import os 
os.chdir('/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8s')
import matplotlib.pyplot as plt
from ultralytics import YOLO
from IPython.display import display, Image
from PIL import Image
import pandas as pd
import numpy as np

# %%
# !yolo detect train model=yolov8s.yaml data="/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/data.yaml" workers=2 batch=12 device=0 epochs=100 patience=50 name=yolov8s_normal_tuned \
lr0=0.00253 lrf=0.00534 momentum=0.81527 weight_decay=0.00044 warmup_epochs=1.04965 warmup_momentum=0.5221 \
hsv_h=0.011 hsv_s=0.17527 hsv_v=0.16854 degrees=0.0 translate=0.02675 scale=0.09048 shear=0.0 perspective=0.0 \
flipud=0.0 fliplr=0.19722 bgr=0.0 mosaic=0.7526 mixup=0.0 copy_paste=0.0
# Out:
# New https://pypi.org/project/ultralytics/8.2.69 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# engine/trainer: task=detect, mode=train, model=yolov8s.yaml, data=/home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/data.yaml, epochs=100, time=None, patience=50, batch=12, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=2, project=None, name=yolov8s_normal_tuned, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.00253, lrf=0.00534, momentum=0.81527, weight_decay=0.00044, warmup_epochs=1.04965, warmup_momentum=0.5221, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.011, hsv_s=0.17527, hsv_v=0.16854, degrees=0.0, translate=0.02675, scale=0.09048, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.19722, bgr=0.0, mosaic=0.7526, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/yolov8s_normal_tuned
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# YOLOv8s summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 123, len(boxes) = 31838. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.12 (you have 1.4.11). Upgrade using: pip install --upgrade albumentations
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/v
# Plotting labels to runs/detect/yolov8s_normal_tuned/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.00253' and 'momentum=0.81527' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0004125), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/yolov8s_normal_tuned
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      4.03G      5.277      2.671      4.028        824        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347   5.65e-05    0.00023   2.89e-05   2.89e-06
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      4.69G      3.169      1.559      3.436        597        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347    0.00203    0.00828    0.00103   0.000229
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      3.87G      2.672      1.315      2.678        852        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347     0.0292      0.119     0.0222    0.00672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.93G      2.523      1.243      2.311        705        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347     0.0846     0.0561     0.0177    0.00591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      3.91G      2.461      1.205      2.206        512        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.496      0.321      0.288      0.102
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.16G      2.377      1.166      2.089        725        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.522      0.532      0.433      0.156
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      4.82G      2.326      1.138      1.999        637        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.757      0.722      0.724      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.03G      2.295      1.122      1.954        710        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.774      0.716      0.749      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      4.52G      2.252      1.092      1.883        760        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.724      0.723      0.719      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.29G      2.236      1.089      1.843        587        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      4.21G      1.502     0.6941      1.318        690        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.942       0.88      0.932      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      4.37G      1.494      0.683      1.311        523        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.929      0.886      0.924      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      4.14G      1.478     0.6861      1.311        665        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.933      0.884      0.932      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      4.58G      1.497     0.6901      1.308        668        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.944      0.878       0.93       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      4.85G      1.448     0.6721      1.289        480        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.929      0.869      0.916      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      4.17G      1.437     0.6719      1.288        478        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.926      0.861      0.904      0.498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      4.29G      1.428     0.6639      1.285        652        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347       0.94      0.887      0.937      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      4.18G      1.415     0.6501      1.271        790        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.951      0.884      0.938      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      4.24G        1.4     0.6554      1.275        686        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.944      0.885       0.94      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      3.87G      1.379     0.6478      1.259        645        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.943      0.894      0.941      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      3.91G      1.351     0.6344      1.236        574        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.942      0.892      0.934      0.536
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      4.96G      1.349     0.6325      1.245        472        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.934      0.901      0.943      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      4.93G      1.342     0.6289      1.239        406        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.949      0.885      0.939       0.54

# %% [markdown]
# # Inference on Test Set

# %%
model = YOLO("/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8s/runs/detect/yolov8s_normal_tuned/weights/best.pt")  

# Creating directory to store results
test_images_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/images'
output_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/YOLOv8s_normal_tuned Inference'
os.makedirs(output_dir, exist_ok=True)

# List of all test images
test_images = [os.path.join(test_images_dir, img) for img in os.listdir(test_images_dir) if img.endswith('.jpg')]
test_images.sort()

# Run inference on all test images
results = model(test_images)  

# Visualize and save the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Save results to disk
    im_rgb.save(os.path.join(output_dir, f"results_{i}.jpg"))
# Out:
# 0: 640x640 89 trees, 8.8ms
# 1: 640x640 7 trees, 8.8ms
# 2: 640x640 47 trees, 8.8ms
# 3: 640x640 46 trees, 8.8ms
# 4: 640x640 46 trees, 8.8ms
# 5: 640x640 46 trees, 8.8ms
# 6: 640x640 68 trees, 8.8ms
# 7: 640x640 69 trees, 8.8ms
# 8: 640x640 69 trees, 8.8ms
# 9: 640x640 69 trees, 8.8ms
# 10: 640x640 70 trees, 8.8ms
# 11: 640x640 109 trees, 8.8ms
# 12: 640x640 112 trees, 8.8ms
# 13: 640x640 112 trees, 8.8ms
# 14: 640x640 112 trees, 8.8ms
# 15: 640x640 111 trees, 8.8ms
# 16: 640x640 98 trees, 8.8ms
# 17: 640x640 121 trees, 8.8ms
# 18: 640x640 171 trees, 8.8ms
# 19: 640x640 17 trees, 8.8ms
# 20: 640x640 76 trees, 8.8ms
# 21: 640x640 76 trees, 8.8ms
# 22: 640x640 77 trees, 8.8ms
# 23: 640x640 76 trees, 8.8ms
# 24: 640x640 91 trees, 8.8ms
# 25: 640x640 91 trees, 8.8ms
# 26: 640x640 91 trees, 8.8ms
# 27: 640x640 91 trees, 8.8ms
# 28: 640x640 91 trees, 8.8ms
# 29: 640x640 77 trees, 8.8ms
# 30: 640x640 77 trees, 8.8ms
# 31: 640x640 77 trees, 8.8ms
# 32: 640x640 77 trees, 8.8ms
# 33: 640x640 156 trees, 8.8ms
# 34: 640x640 116 trees, 8.8ms
# 35: 640x640 115 trees, 8.8ms
# 36: 640x640 116 trees, 8.8ms
# 37: 640x640 116 trees, 8.8ms
# 38: 640x640 72 trees, 8.8ms
# 39: 640x640 71 trees, 8.8ms
# 40: 640x640 72 trees, 8.8ms
# 41: 640x640 72 trees, 8.8ms
# 42: 640x640 76 trees, 8.8ms
# 43: 640x640 49 trees, 8.8ms
# 44: 640x640 130 trees, 8.8ms
# 45: 640x640 130 trees, 8.8ms
# 46: 640x640 130 trees, 8.8ms
# 47: 640x640 130 trees, 8.8ms
# 48: 640x640 130 trees, 8.8ms
# 49: 640x640 94 trees, 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# # Ground Truth

# %%
label_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/labels'

# List of labels
labels = [os.path.join(label_dir, img) for img in os.listdir(label_dir) if img.endswith('.txt')]
labels.sort()

for idx, label in enumerate(labels):
    file = pd.read_csv(label, delimiter=' ', header=None)
    print(f'Ground Truth {idx}: {len(file)} trees')

# %%
predictions = [
    89, 7, 47, 46, 46, 46, 68, 69, 69, 69,
    70, 109, 112, 112, 112, 111, 98, 121, 171, 17,
    76, 76, 77, 76, 91, 91, 91, 91, 91, 77,
    77, 77, 77, 156, 116, 115, 116, 116, 72, 71,
    72, 72, 76, 49, 130, 130, 130, 130, 130, 94
]

ground_truth = [
    86, 7, 48, 48, 48, 48, 64, 69, 69, 69,
    69, 105, 114, 114, 114, 114, 109, 97, 175, 20,
    72, 72, 72, 72, 89, 89, 89, 89, 89, 77,
    77, 77, 77, 148, 112, 112, 112, 112, 72, 72,
    72, 72, 74, 50, 130, 130, 130, 130, 130, 89
]

# Create a DataFrame to store the results
results_df = pd.DataFrame({
    'Image': [f'Image {i}' for i in range(len(predictions))],
    'Prediction': predictions,
    'Ground Truth': ground_truth
})

# Display the dataframe
print(results_df)

# Calculate Mean Absolute Error (MAE)
mae = (results_df['Prediction'] - results_df['Ground Truth']).abs().mean()

print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
#        Image  Prediction  Ground Truth
# 0    Image 0          89            86
# 1    Image 1           7             7
# 2    Image 2          47            48
# 3    Image 3          46            48
# 4    Image 4          46            48
# 5    Image 5          46            48
# 6    Image 6          68            64
# 7    Image 7          69            69
# 8    Image 8          69            69
# 9    Image 9          69            69
# 10  Image 10          70            69
# 11  Image 11         109           105
# 12  Image 12         112           114
# 13  Image 13         112           114
# 14  Image 14         112           114
# 15  Image 15         111           114
# 16  Image 16          98           109
# 17  Image 17         121            97
# 18  Image 18         171           175
# 19  Image 19          17            20
# 20  Image 20          76            72
# 21  Image 21          76            72
# 22  Image 22          77            72
# 23  Image 23          76            72
# 24  Image 24          91            89
# 25  Image 25          91            89
# 26  Image 26          91            89
# 27  Image 27          91            89
# 28  Image 28          91            89
# 29  Image 29          77            77
# 30  Image 30          77            77
# 31  Image 31          77            77
# 32  Image 32          77            77
# 33  Image 33         156           148
# 34  Image 34         116           112
# 35  Image 35         115           112
# 36  Image 36         116           112
# 37  Image 37         116           112
# 38  Image 38          72            72
# 39  Image 39          71            72
# 40  Image 40          72            72
# 41  Image 41          72            72
# 42  Image 42          76            74
# 43  Image 43          49            50
# 44  Image 44         130           130
# 45  Image 45         130           130
# 46  Image 46         130           130
# 47  Image 47         130           130
# 48  Image 48         130           130
# 49  Image 49          94            89
# Mean Absolute Error (MAE): 2.58

# %% [markdown]
# # Training and Tuning YOLOv8-small

# %%
# !yolo detect train model=yolov8s-small.yaml data="/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/data.yaml" workers=2 batch=12 device=0 epochs=100 patience=50 name=yolov8s_small_tuned \
lr0=0.00253 lrf=0.00534 momentum=0.81527 weight_decay=0.00044 warmup_epochs=1.04965 warmup_momentum=0.5221 \
hsv_h=0.011 hsv_s=0.17527 hsv_v=0.16854 degrees=0.0 translate=0.02675 scale=0.09048 shear=0.0 perspective=0.0 \
flipud=0.0 fliplr=0.19722 bgr=0.0 mosaic=0.7526 mixup=0.0 copy_paste=0.0
# Out:
# New https://pypi.org/project/ultralytics/8.2.69 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# engine/trainer: task=detect, mode=train, model=yolov8s-small.yaml, data=/home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/data.yaml, epochs=100, time=None, patience=50, batch=12, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=2, project=None, name=yolov8s_small_tuned, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.00253, lrf=0.00534, momentum=0.81527, weight_decay=0.00044, warmup_epochs=1.04965, warmup_momentum=0.5221, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.011, hsv_s=0.17527, hsv_v=0.16854, degrees=0.0, translate=0.02675, scale=0.09048, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.19722, bgr=0.0, mosaic=0.7526, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/yolov8s_small_tuned
# Overriding model.yaml nc=2 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    115456  ultralytics.nn.modules.block.C2f             [128, 128, 1, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  2   3149824  ultralytics.nn.modules.block.C2f             [512, 512, 2, True]
#   7                  -1  1   1182208  ultralytics.nn.modules.block.SPPF            [512, 1024, 5]
#   8                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#   9             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  10                  -1  1    722432  ultralytics.nn.modules.block.C2f             [1280, 256, 1]
#  11                [10]  1   1369681  ultralytics.nn.modules.head.Detect           [1, [256]]
# YOLOv8s-small summary: 120 layers, 8880017 parameters, 8880001 gradients, 68.6 GFLOPs
#
# Freezing layer 'model.11.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 123, len(boxes) = 31838. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.12 (you have 1.4.11). Upgrade using: pip install --upgrade albumentations
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/v
# Plotting labels to runs/detect/yolov8s_small_tuned/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.00253' and 'momentum=0.81527' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 30 weight(decay=0.0), 33 weight(decay=0.0004125), 32 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect
640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.956      0.929      0.964      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100       5.2G     0.9313     0.4736       1.05        606        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.957       0.93      0.962      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      5.32G     0.9354     0.4718      1.045        449        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.959       0.93      0.965      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      5.21G     0.9334     0.4697      1.042        819        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347       0.95      0.934      0.965      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      5.12G     0.9006      0.461      1.036        787        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.965       0.93      0.964      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      5.61G     0.9301     0.4714      1.045        672        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.962       0.93      0.963      0.657
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      5.14G     0.8955     0.4537      1.034        689        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.952      0.928      0.964       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      5.72G     0.9137     0.4623       1.04        706        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.956      0.934      0.966      0.668
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      5.39G     0.8563     0.4426      1.013        889        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.962      0.934      0.967      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100       5.8G      0.815     0.4334      1.002        548        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.968      0.932      0.969      0.672
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100         5G     0.7847     0.4212     0.9908        598        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.961      0.939      0.972      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      4.98G     0.7862     0.4239     0.9906        656        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.961      0.942      0.968      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      5.12G     0.7523     0.4072     0.9739        638        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.962      0.942      0.966      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      5.01G     0.7827     0.4159     0.9849        568        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.959      0.942      0.966      0.681
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      4.97G     0.7567     0.4075     0.9799        736        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.968      0.939       0.97      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      4.82G     0.7555     0.4099     0.9796        774        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.965      0.936      0.968      0.689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      4.99G     0.7382     0.4035      0.971        521        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.966      0.937      0.969      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      5.29G     0.7467     0.4054     0.9758        676        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.967      0.938      0.969      0.691
#
# 100 epochs completed in 0.319 hours.
# Optimizer stripped from runs/detect/yolov8s_small_tuned/weights/last.pt, 17.9MB
# Optimizer stripped from runs/detect/yolov8s_small_tuned/weights/best.pt, 17.9MB
#
# Validating runs/detect/yolov8s_small_tuned/weights/best.pt...
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# YOLOv8s-small summary (fused): 90 layers, 8872913 parameters, 0 gradients, 68.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.966      0.937      0.969      0.693
# Speed: 1.3ms preprocess, 8.1ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs/detect/yolov8s_small_tuned
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# # Inference on Test Set

# %%
model = YOLO("/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8s/runs/detect/yolov8s_small_tuned/weights/best.pt")  

# Creating directory to store results
test_images_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/images'
output_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/YOLOv8s_small_tuned Inference'
os.makedirs(output_dir, exist_ok=True)

# List of all test images
test_images = [os.path.join(test_images_dir, img) for img in os.listdir(test_images_dir) if img.endswith('.jpg')]
test_images.sort()

# Run inference on all test images
results = model(test_images)  

# Visualize and save the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Save results to disk
    im_rgb.save(os.path.join(output_dir, f"results_{i}.jpg"))

# %%
predictions = [
    89, 6, 49, 49, 49, 49, 68, 67, 67, 67,
    68, 106, 113, 113, 113, 114, 98, 99, 178, 21,
    77, 77, 77, 77, 86, 86, 87, 87, 87, 78,
    78, 78, 79, 121, 116, 116, 116, 116, 74, 75,
    74, 74, 73, 49, 131, 131, 131, 131, 131, 95
]

ground_truth = [
    86, 7, 48, 48, 48, 48, 64, 69, 69, 69,
    69, 105, 114, 114, 114, 114, 109, 97, 175, 20,
    72, 72, 72, 72, 89, 89, 89, 89, 89, 77,
    77, 77, 77, 148, 112, 112, 112, 112, 72, 72,
    72, 72, 74, 50, 130, 130, 130, 130, 130, 89
]

# Create a DataFrame to store the results
results_df = pd.DataFrame({
    'Image': [f'Image {i}' for i in range(len(predictions))],
    'Prediction': predictions,
    'Ground Truth': ground_truth
})

# Display the dataframe
print(results_df)

# Calculate Mean Absolute Error (MAE)
mae = (results_df['Prediction'] - results_df['Ground Truth']).abs().mean()

print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
#        Image  Prediction  Ground Truth
# 0    Image 0          89            86
# 1    Image 1           6             7
# 2    Image 2          49            48
# 3    Image 3          49            48
# 4    Image 4          49            48
# 5    Image 5          49            48
# 6    Image 6          68            64
# 7    Image 7          67            69
# 8    Image 8          67            69
# 9    Image 9          67            69
# 10  Image 10          68            69
# 11  Image 11         106           105
# 12  Image 12         113           114
# 13  Image 13         113           114
# 14  Image 14         113           114
# 15  Image 15         114           114
# 16  Image 16          98           109
# 17  Image 17          99            97
# 18  Image 18         178           175
# 19  Image 19          21            20
# 20  Image 20          77            72
# 21  Image 21          77            72
# 22  Image 22          77            72
# 23  Image 23          77            72
# 24  Image 24          86            89
# 25  Image 25          86            89
# 26  Image 26          87            89
# 27  Image 27          87            89
# 28  Image 28          87            89
# 29  Image 29          78            77
# 30  Image 30          78            77
# 31  Image 31          78            77
# 32  Image 32          79            77
# 33  Image 33         121           148
# 34  Image 34         116           112
# 35  Image 35         116           112
# 36  Image 36         116           112
# 37  Image 37         116           112
# 38  Image 38          74            72
# 39  Image 39          75            72
# 40  Image 40          74            72
# 41  Image 41          74            72
# 42  Image 42          73            74
# 43  Image 43          49            50
# 44  Image 44         131           130
# 45  Image 45         131           130
# 46  Image 46         131           130
# 47  Image 47         131           130
# 48  Image 48         131           130
# 49  Image 49          95            89
# Mean Absolute Error (MAE): 2.84

# %% [markdown]
# ## YOLOv8s-small with it's own hyperparameters but same augmentation

# %%
# !yolo detect train model=yolov8s-small.yaml data="/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/data.yaml" workers=2 batch=12 device=0 epochs=100 patience=50 name=yolov8s_small_tuned_parameters_same_aug \
lr0=0.00233 lrf=0.01158 momentum=0.82094 weight_decay=0.00073 warmup_epochs=3.72712 warmup_momentum=0.48724 \
hsv_h=0.011 hsv_s=0.17527 hsv_v=0.16854 degrees=0.0 translate=0.02675 scale=0.09048 shear=0.0 perspective=0.0 \
flipud=0.0 fliplr=0.19722 bgr=0.0 mosaic=0.7526 mixup=0.0 copy_paste=0.0
# Out:
# New https://pypi.org/project/ultralytics/8.2.70 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# engine/trainer: task=detect, mode=train, model=yolov8s-small.yaml, data=/home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/data.yaml, epochs=100, time=None, patience=50, batch=12, imgsz=640, save=True, save_period=-1, cache=False, device=0, workers=2, project=None, name=yolov8s_small_tuned_parameters_same_aug, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.00233, lrf=0.01158, momentum=0.82094, weight_decay=0.00073, warmup_epochs=3.72712, warmup_momentum=0.48724, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.011, hsv_s=0.17527, hsv_v=0.16854, degrees=0.0, translate=0.02675, scale=0.09048, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.19722, bgr=0.0, mosaic=0.7526, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/yolov8s_small_tuned_parameters_same_aug
# Overriding model.yaml nc=2 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    115456  ultralytics.nn.modules.block.C2f             [128, 128, 1, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  2   3149824  ultralytics.nn.modules.block.C2f             [512, 512, 2, True]
#   7                  -1  1   1182208  ultralytics.nn.modules.block.SPPF            [512, 1024, 5]
#   8                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#   9             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  10                  -1  1    722432  ultralytics.nn.modules.block.C2f             [1280, 256, 1]
#  11                [10]  1   1369681  ultralytics.nn.modules.head.Detect           [1, [256]]
# YOLOv8s-small summary: 120 layers, 8880017 parameters, 8880001 gradients, 68.6 GFLOPs
#
# Freezing layer 'model.11.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 123, len(boxes) = 31838. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.12 (you have 1.4.11). Upgrade using: pip install --upgrade albumentations
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /home/jupyter/ee_tree_counting/Data/Combined Dataset YOLO No Aug/v
# Plotting labels to runs/detect/yolov8s_small_tuned_parameters_same_aug/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.00233' and 'momentum=0.82094' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 30 weight(decay=0.0), 33 weight(decay=0.0006843750000000001), 32 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/yolov8s_small_tuned_parameters_same_aug
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      5.08G        4.6      2.301      3.788        824        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347    0.00672     0.0274    0.00549    0.00128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      5.12G      2.876      1.372      2.759        597        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347    0.00352      0.014    0.00178    0.00048
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      4.82G      2.554      1.249      2.341        852        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347    0.00492       0.02    0.00255    0.00073
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      5.84G      2.438      1.195       2.14        705        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347       0.39      0.322      0.264     0.0964
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      5.05G      2.361      1.203      2.053        512        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.374      0.348      0.237     0.0757
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      5.23G      2.334      1.157      1.981        725        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.662      0.654      0.611      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100       5.6G      2.301      1.157      1.926        637        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.763       0.73      0.734      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      5.14G      2.224      1.126      1.873        710        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.723      0.691      0.714      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      5.56G      2.176      1.102      1.823        760        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.777      0.732      0.757      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100       5.3G      2.196      1.081      1.796        587        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.793      0.753       0.77      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      5.16G       2.13      1.096      1.769        649        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347       0.78      0.717      0.718      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.87G      2.111      1.069      1.731        496        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.746      0.687      0.662      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      5.09G      2.042      1.048      1.707        749        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.798       0.77      0.771      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      5.34G      2.022      1.039      1.665        540        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.751      0.738      0.747      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.98G      2.011      1.026      1.674        541        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.848      0.789      0.822      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      5.15G      2.004      1.013      1.651        611        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.783      0.768      0.792      0.352
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      5.28G      1.974      1.031      1.631        559        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.847      0.779        0.8      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      5.29G     0.7207     0.3974     0.9643        676        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.966      0.946       0.97      0.706
#
# 100 epochs completed in 0.306 hours.
# Optimizer stripped from runs/detect/yolov8s_small_tuned_parameters_same_aug/weights/last.pt, 17.9MB
# Optimizer stripped from runs/detect/yolov8s_small_tuned_parameters_same_aug/weights/best.pt, 17.9MB
#
# Validating runs/detect/yolov8s_small_tuned_parameters_same_aug/weights/best.pt...
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.14 torch-1.13.1+cu117 CUDA:0 (Tesla T4, 14918MiB)
# YOLOv8s-small summary (fused): 90 layers, 8872913 parameters, 0 gradients, 68.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         59       4347      0.961      0.948      0.971       0.71
# Speed: 1.3ms preprocess, 10.1ms inference, 0.0ms loss, 6.1ms postprocess per image
# Results saved to runs/detect/yolov8s_small_tuned_parameters_same_aug
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# # Inference on Test Set

# %%
model = YOLO("/home/jupyter/ee_tree_counting/Models/YOLOv8 Architecture/YOLOv8s/runs/detect/yolov8s_small_tuned_parameters_same_aug/weights/best.pt")  

# Creating directory to store results
test_images_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/images'
output_dir = '/home/jupyter/ee_tree_counting/Data/Final Tree Dataset YOLO/test/YOLOv8s_small_tuned_parameters_same_aug Inference'
os.makedirs(output_dir, exist_ok=True)

# List of all test images
test_images = [os.path.join(test_images_dir, img) for img in os.listdir(test_images_dir) if img.endswith('.jpg')]
test_images.sort()

# Run inference on all test images
results = model(test_images)  

# Visualize and save the results
for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Save results to disk
    im_rgb.save(os.path.join(output_dir, f"results_{i}.jpg"))
# Out:
# 0: 640x640 87 trees, 17.1ms
# 1: 640x640 5 trees, 17.1ms
# 2: 640x640 51 trees, 17.1ms
# 3: 640x640 50 trees, 17.1ms
# 4: 640x640 50 trees, 17.1ms
# 5: 640x640 50 trees, 17.1ms
# 6: 640x640 65 trees, 17.1ms
# 7: 640x640 67 trees, 17.1ms
# 8: 640x640 67 trees, 17.1ms
# 9: 640x640 67 trees, 17.1ms
# 10: 640x640 67 trees, 17.1ms
# 11: 640x640 110 trees, 17.1ms
# 12: 640x640 108 trees, 17.1ms
# 13: 640x640 108 trees, 17.1ms
# 14: 640x640 108 trees, 17.1ms
# 15: 640x640 108 trees, 17.1ms
# 16: 640x640 102 trees, 17.1ms
# 17: 640x640 91 trees, 17.1ms
# 18: 640x640 174 trees, 17.1ms
# 19: 640x640 17 trees, 17.1ms
# 20: 640x640 76 trees, 17.1ms
# 21: 640x640 76 trees, 17.1ms
# 22: 640x640 76 trees, 17.1ms
# 23: 640x640 76 trees, 17.1ms
# 24: 640x640 91 trees, 17.1ms
# 25: 640x640 91 trees, 17.1ms
# 26: 640x640 91 trees, 17.1ms
# 27: 640x640 91 trees, 17.1ms
# 28: 640x640 91 trees, 17.1ms
# 29: 640x640 79 trees, 17.1ms
# 30: 640x640 79 trees, 17.1ms
# 31: 640x640 79 trees, 17.1ms
# 32: 640x640 79 trees, 17.1ms
# 33: 640x640 100 trees, 17.1ms
# 34: 640x640 119 trees, 17.1ms
# 35: 640x640 120 trees, 17.1ms
# 36: 640x640 119 trees, 17.1ms
# 37: 640x640 119 trees, 17.1ms
# 38: 640x640 72 trees, 17.1ms
# 39: 640x640 71 trees, 17.1ms
# 40: 640x640 72 trees, 17.1ms
# 41: 640x640 72 trees, 17.1ms
# 42: 640x640 74 trees, 17.1ms
# 43: 640x640 51 trees, 17.1ms
# 44: 640x640 131 trees, 17.1ms
# 45: 640x640 130 trees, 17.1ms
# 46: 640x640 130 trees, 17.1ms
# 47: 640x640 131 trees, 17.1ms
# 48: 640x640 131 trees, 17.1ms
# 49: 640x640 88 trees, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
predictions = [
    87, 5, 51, 50, 50, 50, 65, 67, 67, 67,
    67, 110, 108, 108, 108, 108, 102, 91, 174, 17,
    76, 76, 76, 76, 91, 91, 91, 91, 91, 79,
    79, 79, 79, 100, 119, 120, 119, 119, 72, 71,
    72, 72, 74, 51, 131, 130, 130, 131, 131, 88
]

ground_truth = [
    86, 7, 48, 48, 48, 48, 64, 69, 69, 69,
    69, 105, 114, 114, 114, 114, 109, 97, 175, 20,
    72, 72, 72, 72, 89, 89, 89, 89, 89, 77,
    77, 77, 77, 148, 112, 112, 112, 112, 72, 72,
    72, 72, 74, 50, 130, 130, 130, 130, 130, 89
]

# Create a DataFrame to store the results
results_df = pd.DataFrame({
    'Image': [f'Image {i}' for i in range(len(predictions))],
    'Prediction': predictions,
    'Ground Truth': ground_truth
})

# Display the dataframe
print(results_df)

# Calculate Mean Absolute Error (MAE)
mae = (results_df['Prediction'] - results_df['Ground Truth']).abs().mean()

print(f"Mean Absolute Error (MAE): {mae:.2f}")
# Out:
#        Image  Prediction  Ground Truth
# 0    Image 0          87            86
# 1    Image 1           5             7
# 2    Image 2          51            48
# 3    Image 3          50            48
# 4    Image 4          50            48
# 5    Image 5          50            48
# 6    Image 6          65            64
# 7    Image 7          67            69
# 8    Image 8          67            69
# 9    Image 9          67            69
# 10  Image 10          67            69
# 11  Image 11         110           105
# 12  Image 12         108           114
# 13  Image 13         108           114
# 14  Image 14         108           114
# 15  Image 15         108           114
# 16  Image 16         102           109
# 17  Image 17          91            97
# 18  Image 18         174           175
# 19  Image 19          17            20
# 20  Image 20          76            72
# 21  Image 21          76            72
# 22  Image 22          76            72
# 23  Image 23          76            72
# 24  Image 24          91            89
# 25  Image 25          91            89
# 26  Image 26          91            89
# 27  Image 27          91            89
# 28  Image 28          91            89
# 29  Image 29          79            77
# 30  Image 30          79            77
# 31  Image 31          79            77
# 32  Image 32          79            77
# 33  Image 33         100           148
# 34  Image 34         119           112
# 35  Image 35         120           112
# 36  Image 36         119           112
# 37  Image 37         119           112
# 38  Image 38          72            72
# 39  Image 39          71            72
# 40  Image 40          72            72
# 41  Image 41          72            72
# 42  Image 42          74            74
# 43  Image 43          51            50
# 44  Image 44         131           130
# 45  Image 45         130           130
# 46  Image 46         130           130
# 47  Image 47         131           130
# 48  Image 48         131           130
# 49  Image 49          88            89
# Mean Absolute Error (MAE): 3.68
